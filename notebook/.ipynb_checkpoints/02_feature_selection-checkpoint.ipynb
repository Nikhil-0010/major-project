# %%
# Cell 1 — imports + setup
import os, json
import numpy as np, pandas as pd
from pathlib import Path
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
from xgboost import XGBClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
import joblib
import sys
sys.path.append("..")

from src.transforms import (
    get_preprocessor,
    get_preprocessor_fixed,
    compute_categories_list,
    numeric_features,
    categorical_features,
    select_cols_indices,
    get_feature_names_from_preprocessor  # if present; else the notebook provides fallback
)
from src.artifacts import ensure_artifact_dirs, save_joblib_with_manifest, save_json_with_manifest

# constants
SEED = 42
ART_ROOT = "../artifacts"
FS_DIR = os.path.join(ART_ROOT, "feature_selection")
os.makedirs(FS_DIR, exist_ok=True)
ensure_artifact_dirs()
# Out:
# '..\\artifacts'

# %%
# Cell 2 — load cleaned data and train/hold split (use canonical splits saved earlier)
df = pd.read_csv("../artifacts/data/heart_uci_clean.csv")  # or ../data/...
print("Loaded df shape:", df.shape)

# Ensure target is binary as expected
df['num'] = (df['num'] > 0).astype(int)

# Defensive: if missing indicator columns present, ensure they are numeric
for c in ['ca_missing','thal_missing']:
    if c in df.columns:
        df[c] = df[c].fillna(0).astype(int)

X = df.drop(columns=["num"])
y = df["num"].values

# use saved train/hold if present, else create and save them
train_path = os.path.join(ART_ROOT, "data", "train.csv")
hold_path  = os.path.join(ART_ROOT, "data", "holdout.csv")

if Path(train_path).exists() and Path(hold_path).exists():
    train_df = pd.read_csv(train_path)
    hold_df  = pd.read_csv(hold_path)
    X_train = train_df.drop(columns=["num"])
    y_train = train_df["num"].values
    X_hold  = hold_df.drop(columns=["num"])
    y_hold  = hold_df["num"].values
    print("Loaded existing train/hold CSVs.")
else:
    X_train, X_hold, y_train, y_hold = train_test_split(
        X, y, test_size=0.20, random_state=SEED, stratify=y
    )
    # save them for reproducibility
    pd.concat([X_train, pd.Series(y_train, name="num")], axis=1).to_csv(train_path, index=False)
    pd.concat([X_hold, pd.Series(y_hold, name="num")], axis=1).to_csv(hold_path, index=False)
    print("Created and saved train/hold CSVs.")

print("Train shape:", X_train.shape, "Hold shape:", X_hold.shape)
# Out:
# Loaded df shape: (920, 16)
# Loaded existing train/hold CSVs.
# Train shape: (736, 15) Hold shape: (184, 15)

# %%
# --- Cell 3: Fit a *fixed* preprocessor on TRAIN only and get feature names ---
from src.transforms import get_preprocessor, get_preprocessor_fixed, compute_categories_list, get_feature_names_from_preprocessor
# load train/hold created earlier
train_df = pd.read_csv(os.path.join(ART_ROOT, "data", "train.csv"))
X_train = train_df.drop(columns=["num"])
y_train = train_df["num"].values

# Compute categories list from training set (ensures consistent one-hot shape)
categories_list = compute_categories_list(X_train, categorical_features)
# Build a preprocessor that uses these explicit categories (unfitted)
preproc_fixed = get_preprocessor_fixed(categories_list=categories_list)

# Fit the fixed preprocessor on training data (important)
preproc_fixed.fit(X_train)
X_train_trans = preproc_fixed.transform(X_train)   # dense array

# get feature names exactly in the order of the transformed array
full_feature_names = get_feature_names_from_preprocessor(preproc_fixed, X_train.columns.tolist())
print("Total transformed features:", len(full_feature_names))
print(full_feature_names[:40])

# Save the feature-index map (so other notebooks use the same mapping)
featmap = {
    "full_feature_names": full_feature_names,
    "numeric_features": numeric_features,
    "categorical_features": categorical_features,
    "categories_list": categories_list
}
save_json_with_manifest(featmap, os.path.join(FS_DIR, "feature_index_map.json"), name="feature_index_map")
print("Saved/updated feature_index_map.json")
# Out:
# Total transformed features: 25
# ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'sex_Female', 'sex_Male', 'cp_asymptomatic', 'cp_atypical angina', 'cp_non-anginal', 'cp_typical angina', 'fbs_False', 'fbs_True', 'restecg_lv hypertrophy', 'restecg_normal', 'restecg_st-t abnormality', 'exang_False', 'exang_True', 'slope_downsloping', 'slope_flat', 'slope_upsloping', 'thal_fixed defect', 'thal_normal', 'thal_reversable defect']
# Saved/updated feature_index_map.json

# %%
# Cell 4 — RFE ranking on transformed matrix (fast XGB base)
# --- Cell 4: RFE ranking (use the SAME fitted preprocessor output for ranking) ---
# Use X_train_trans computed above
from xgboost import XGBClassifier
from sklearn.feature_selection import RFE

xgb_rfe = XGBClassifier(eval_metric='logloss',
                        random_state=SEED, n_estimators=100, max_depth=3)
rfe = RFE(estimator=xgb_rfe, n_features_to_select=1, step=1)
rfe.fit(X_train_trans, y_train)
ranks = rfe.ranking_

df_rank = pd.DataFrame({"feature": full_feature_names, "rank": ranks})
df_rank = df_rank.sort_values("rank").reset_index(drop=True)
df_rank.to_csv(os.path.join(FS_DIR, "feature_ranks.csv"), index=False)
save_json_with_manifest(df_rank.to_dict(orient="records"),
                        os.path.join(FS_DIR, "feature_ranks.json"), name="feature_ranks")
print("Saved feature_ranks (csv + json). Top features:", df_rank['feature'].tolist()[:10])
# Out:
# Saved feature_ranks (csv + json). Top features: ['cp_asymptomatic', 'cp_atypical angina', 'sex_Female', 'thal_normal', 'ca', 'chol', 'oldpeak', 'age', 'slope_flat', 'thal_reversable defect']

# %%
# --- Cell 5: Top-K CV using reproducible preprocessor inside the pipeline ---
from sklearn.preprocessing import FunctionTransformer
from src.transforms import select_cols_indices

KMAX = min(25, len(full_feature_names))
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
results = []

for k in range(1, KMAX+1):
    top_features = df_rank['feature'].tolist()[:k]
    top_indices = [full_feature_names.index(f) for f in top_features]

    # portable selector (uses top-level select_cols_indices)
    selector = FunctionTransformer(func=select_cols_indices, kw_args={"indices": top_indices}, validate=False)

    # IMPORTANT: create preprocessor inside pipeline using the SAME categories_list
    pipe = Pipeline([
        ("preproc", get_preprocessor_fixed(categories_list)),   # unfitted preprocessor but with fixed categories
        ("selector", selector),
        ("xgb", XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=SEED))
    ])

    # cross-val scoring
    aucs = cross_val_score(pipe, X_train, y_train, cv=skf, scoring='roc_auc', n_jobs=1)
    aps  = cross_val_score(pipe, X_train, y_train, cv=skf, scoring='average_precision', n_jobs=1)

    mean_auc = float(np.mean(aucs))
    std_auc  = float(np.std(aucs))
    mean_ap  = float(np.mean(aps))
    std_ap   = float(np.std(aps))

    # fit on full training for reference and save (preprocessor will be fitted inside pipe.fit)
    pipe.fit(X_train, y_train)
    out_path = os.path.join(FS_DIR, f"pipeline_top{k}.joblib")
    save_joblib_with_manifest(pipe, out_path, name=f"pipeline_top{k}", notes=f"top-{k} features")

    results.append({
        "k": k,
        "n_features": k,
        "mean_auc": mean_auc,
        "std_auc": std_auc,
        "mean_avg_precision": mean_ap,
        "std_avg_precision": std_ap,
        "model_artifact": out_path,
        "model_size_bytes": Path(out_path).stat().st_size
    })

    print(f"k={k} -> mean_auc={mean_auc:.4f} mean_ap={mean_ap:.4f} saved:{out_path}")

# Save results
df_results = pd.DataFrame(results)
df_results.to_csv(os.path.join(FS_DIR, "topk_results.csv"), index=False)
save_json_with_manifest(df_results.to_dict(orient="records"), os.path.join(FS_DIR, "topk_results.json"), name="topk_results")
print("Saved topk_results.csv and .json")
# Out:
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:20] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:20] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=1 -> mean_auc=0.7465 mean_ap=0.7257 saved:../artifacts\feature_selection\pipeline_top1.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=2 -> mean_auc=0.7720 mean_ap=0.7450 saved:../artifacts\feature_selection\pipeline_top2.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=3 -> mean_auc=0.8063 mean_ap=0.7824 saved:../artifacts\feature_selection\pipeline_top3.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=4 -> mean_auc=0.8267 mean_ap=0.8169 saved:../artifacts\feature_selection\pipeline_top4.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:30] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=5 -> mean_auc=0.8347 mean_ap=0.8307 saved:../artifacts\feature_selection\pipeline_top5.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:30] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:30] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:31] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:32] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:32] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=6 -> mean_auc=0.8072 mean_ap=0.8173 saved:../artifacts\feature_selection\pipeline_top6.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:32] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:32] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:32] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:33] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:34] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:34] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=7 -> mean_auc=0.8239 mean_ap=0.8417 saved:../artifacts\feature_selection\pipeline_top7.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:34] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:34] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:35] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:35] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:35] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:35] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:36] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:36] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:36] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:36] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:38] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=8 -> mean_auc=0.8273 mean_ap=0.8335 saved:../artifacts\feature_selection\pipeline_top8.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:38] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:39] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:39] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:39] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:40] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:40] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:40] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=9 -> mean_auc=0.8373 mean_ap=0.8447 saved:../artifacts\feature_selection\pipeline_top9.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:41] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:42] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:43] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:43] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=10 -> mean_auc=0.8401 mean_ap=0.8493 saved:../artifacts\feature_selection\pipeline_top10.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:43] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:44] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:44] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:44] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:44] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:45] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:45] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:45] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:46] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:46] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:46] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=11 -> mean_auc=0.8423 mean_ap=0.8482 saved:../artifacts\feature_selection\pipeline_top11.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:47] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:48] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:48] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:49] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:49] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:49] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:49] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:50] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:50] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:50] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:50] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=12 -> mean_auc=0.8415 mean_ap=0.8426 saved:../artifacts\feature_selection\pipeline_top12.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:51] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:51] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:51] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:51] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:51] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:52] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:52] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:52] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:52] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:53] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:53] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=13 -> mean_auc=0.8442 mean_ap=0.8501 saved:../artifacts\feature_selection\pipeline_top13.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:53] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:54] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:54] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:54] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:54] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:55] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:55] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:55] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:56] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:56] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:56] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=14 -> mean_auc=0.8448 mean_ap=0.8492 saved:../artifacts\feature_selection\pipeline_top14.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:57] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:57] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:57] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:57] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:58] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:58] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:58] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:58] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:59] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:59] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:59] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=15 -> mean_auc=0.8542 mean_ap=0.8531 saved:../artifacts\feature_selection\pipeline_top15.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:59] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:44:59] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:00] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:00] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:00] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:01] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:15] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=20 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top20.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:15] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:15] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:16] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:16] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:16] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:16] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:16] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=21 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top21.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:17] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:18] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:18] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:18] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:18] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:18] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:19] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:19] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:19] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:19] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=22 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top22.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:20] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:20] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:20] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:21] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:22] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=23 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top23.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:23] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:24] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:25] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=24 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top24.joblib
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:26] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:27] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:28] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Nikhil\anaconda3\envs\heartenv\Lib\site-packages\xgboost\training.py:199: UserWarning: [11:45:29] WARNING: D:\bld\xgboost-split_1764148481205\work\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# k=25 -> mean_auc=0.8446 mean_ap=0.8442 saved:../artifacts\feature_selection\pipeline_top25.joblib
# Saved topk_results.csv and .json

# %%
# Cell 6 — plot accuracy vs k (matplotlib inline)
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.errorbar(df_results['k'], df_results['mean_auc'], yerr=df_results['std_auc'], label="ROC-AUC", marker='o')
plt.errorbar(df_results['k'], df_results['mean_avg_precision'], yerr=df_results['std_avg_precision'], label="Avg Precision", marker='s')
plt.xlabel("Number of transformed features (k)")
plt.ylabel("Score")
plt.title("Performance vs Number of features (Top-k)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(FS_DIR, "topk_performance.png"), dpi=200)
plt.show()

# %%
# Out:
# train.shape (736, 16) hold.shape (184, 16)
# train.value_counts target:
#  {1: 407, 0: 329}
# hold.value_counts target:
#  {1: 102, 0: 82}
